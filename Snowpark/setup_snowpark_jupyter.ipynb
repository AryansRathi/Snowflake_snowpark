# %%
def fun():
    for x in range(22,23,24):
        print(x)
fun()
# Out:
# 22

# %%
import pandas as pd
from tabulate import tabulate
from utils import snowpark_utils

# Get the Snowpark session
session = snowpark_utils.get_snowpark_session()

# SQL query
query = "select * from SNOWFLAKE_SAMPLE_DATA.INFORMATION_SCHEMA.ENABLED_ROLES;"

# Execute the query and fetch results
df = session.sql(query).toPandas()

# Set the display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Formatting the table
formatted_table = tabulate(df, headers='keys', tablefmt='psql')

# Print the formatted table
print(formatted_table)

# Close the Snowpark session
session.close()
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Going to open: https://login.microsoftonline.com/3d0a5a71-aa06-4790-9185-8796f123cf92/saml2?SAMLRequest=lZJdb9owGIX%2FSuRdJ3bCV2IRKgZDhbUbKtBqvTOxAx6OndoOgf36OQGk7qKVdhc55%2Fg5fs87vDsVwjsybbiSKQgDBDwmM0W53KVgs575MfCMJZISoSRLwZkZcDcaGlKIEo8ru5dP7K1ixnruImlw8yMFlZZYEcMNlqRgBtsMr8aPDzgKECbGMG0dDlwt1HDH2ltbYgjrug7qTqD0DkYIIYgS6FSN5At4hyg%2FZ5RaWZUpcbOc3Js%2BQIQQdRuEUzjC8mr8yuVlBJ9RtheRwffr9dJf%2FlytgTe%2BvW6ipKkKpldMH3nGNk8PlwDGJSBvFRfEz0jJLRGBkarOBTmwTBVlZd2VgfuCOaNQqB13g5pPU1AeOI23g%2Fvx%2Bduv2eOW09fFy4HWC7n7veWL2WT35%2FtkX78k28nz6XzcZMB7vtUaNbXOjanYXDZlWneEoo6PBn4Yr0OEwxh3kyDp9V%2BBN3Vlckls67wlbnMEBc%2B0Miq3SgouWZuyQxHpkUHoE4L6fneQID8J454fD5J%2BHkadLE8i2FQWgcva4DaIHv3XMIbwvfW6fj9cI%2FPpUgmenb2Z0gWxHxcWBmF7wqmft1LMCsLFmFLNjHHFCaHqiWbEui23umIAji7Uf%2Fd89Bc%3D&RelayState=59365 to authenticate...
# Connection is working.
# +-----+--------------------------------------------------------------+-----------------+
# |     | ROLE_NAME                                                    | ROLE_OWNER      |
# |-----+--------------------------------------------------------------+-----------------|
# |   0 | DATABASE_AQUILA_DEV_R                                        | SYSADMIN        |
# |   1 | DATABASE_AQUILA_PROD_R                                       | SYSADMIN        |
# |   2 | PUBLIC                                                       |                 |
# |   3 | SCHEMA_DBT_ABABY_DEV_R                                       | ACCOUNTADMIN    |
# |   4 | SCHEMA_DBT_ABUGROV_DEV_R                                     | SECURITYADMIN   |
# |   5 | SCHEMA_DBT_ANALYTICS_DEV_R                                   | SECURITYADMIN   |
# |   6 | SCHEMA_DBT_ANALYTICS_PROD_R                                  | SECURITYADMIN   |
# |   7 | SCHEMA_DBT_ANALYTICS_TEST_R                                  | SECURITYADMIN   |
# |   8 | SCHEMA_DBT_ARATHI_DEV_R                                      | ACCOUNTADMIN    |
# |   9 | SCHEMA_DBT_EDUKAJ_DEV_R                                      | SECURITYADMIN   |
# |  10 | SCHEMA_DBT_JPANESAR_DEV_R                                    | SECURITYADMIN   |
# |  11 | SCHEMA_DBT_KBYCHKOVSKA_DEV_R                                 | ACCOUNTADMIN    |
# |  12 | SCHEMA_DBT_KNEINSTELL_DEV_R                                  | SECURITYADMIN   |
# |  13 | SCHEMA_DBT_LCABELLO_DEV_R                                    | ACCOUNTADMIN    |
# |  14 | SCHEMA_DBT_LDERVISHEV_DEV_R                                  | SECURITYADMIN   |
# |  15 | SCHEMA_DBT_MBUETTGENBACH_DEV_R                               | SECURITYADMIN   |
# |  16 | SCHEMA_DBT_MLEIST_DEV_R                                      | SECURITYADMIN   |
# |  17 | SCHEMA_DBT_MLUETTGE_DEV_R                                    | SECURITYADMIN   |
# |  18 | SCHEMA_DBT_MSERHIICHUK_DEV_R                                 | SECURITYADMIN   |
# |  19 | SCHEMA_DBT_MTSVETKOV_DEV_R                                   | ACCOUNTADMIN    |
# |  20 | SCHEMA_DBT_SKUEHNE_DEV_R                                     | SECURITYADMIN   |
# |  21 | SCHEMA_DBT_SSAJAN_DEV_R                                      | ACCOUNTADMIN    |
# |  22 | SCHEMA_DBT_TSOTIROV_DEV_R                                    | SECURITYADMIN   |
# |  23 | SCHEMA_DBT_YZHANG_DEV_R                                      | SECURITYADMIN   |
# |  24 | SCHEMA_DEP_ENERGYINFRASTRUCTURE_DEV_R                        | SECURITYADMIN   |
# |  25 | SCHEMA_DEP_FINANCE_DEV_R                                     | SECURITYADMIN   |
# |  26 | SCHEMA_DEP_RISK_ANALYTICS_DEV_R                              | SECURITYADMIN   |
# |  27 | SCHEMA_DWH_BUSINESS_CORE_TEST_R                              | SECURITYADMIN   |
# |  28 | SCHEMA_DWH_META_DEV_R                                        | SECURITYADMIN   |
# |  29 | SCHEMA_DWH_REFERENCE_TEST_R                                  | ACCOUNTADMIN    |
# |  30 | SCHEMA_DWH_REPORTING_TEST_R                                  | SECURITYADMIN   |
# |  31 | SCHEMA_RAW_BREEZE_DEV_R                                      | SECURITYADMIN   |
# |  32 | SCHEMA_RAW_BREEZE_TEST_R                                     | SECURITYADMIN   |
# |  33 | SCHEMA_RAW_CODE_REFERENCE_TABLES_DEV_R                       | SECURITYADMIN   |
# |  34 | SCHEMA_RAW_DYNAMO_TEST_R                                     | SECURITYADMIN   |
# |  35 | SCHEMA_RAW_EU_DEPO_BANK_TEST_R                               | SECURITYADMIN   |
# |  36 | SCHEMA_RAW_FAST_MODEL_PROD_R                                 | SECURITYADMIN   |
# |  37 | SCHEMA_RAW_IRRADIATION_PROD_R                                | SECURITYADMIN   |
# |  38 | SCHEMA_RAW_JIRA_PROD_R                                       | SECURITYADMIN   |
# |  39 | SCHEMA_DBT_KCHAUDHARY_DEV_R                                  | SECURITYADMIN   |
# |  40 | SCHEMA_DBT_RGERMANOVA_DEV_R                                  | SECURITYADMIN   |
# |  41 | SCHEMA_DBT_SBAHMANI_DEV_R                                    | SECURITYADMIN   |
# |  42 | SCHEMA_DBT_VDAS_DEV_R                                        | ACCOUNTADMIN    |
# |  43 | SCHEMA_DBT_ZVOLARIC_DEV_R                                    | ACCOUNTADMIN    |
# |  44 | SCHEMA_DEP_DP_DEV_R                                          | ACCOUNTADMIN    |
# |  45 | SCHEMA_DEP_RISK_ANALYTICS_PROD_R                             | ACCOUNTADMIN    |
# |  46 | SCHEMA_DWH_META_TEST_R                                       | SECURITYADMIN   |
# |  47 | SCHEMA_MARKET_DATA_DEV_R                                     | SECURITYADMIN   |
# |  48 | SCHEMA_RAW_AIFEXPERT_DEV_R                                   | SECURITYADMIN   |
# |  49 | SCHEMA_RAW_AIFEXPERT_PROD_R                                  | SECURITYADMIN   |
# |  50 | SCHEMA_RAW_ASEPREL_TEST_R                                    | SECURITYADMIN   |
# |  51 | SCHEMA_RAW_DYNAMO_PROD_R                                     | SECURITYADMIN   |
# |  52 | SCHEMA_RAW_ESG_TEST_R                                        | ACCOUNTADMIN    |
# |  53 | SCHEMA_RAW_METEOCONTROL_DEV_R                                | SECURITYADMIN   |
# |  54 | SCHEMA_RAW_NEO_DEV_R                                         | ACCOUNTADMIN    |
# |  55 | SCHEMA_REPORTING_COLLIBRA_PROD_R                             | SECURITYADMIN   |
# |  56 | SCHEMA_REPORTING_FINANCE_OPERATIONS_EUROPE_N_AND_S_DEV_R     | SECURITYADMIN   |
# |  57 | SCHEMA_REPORTING_QBI_PROD_R                                  | SECURITYADMIN   |
# |  58 | SCHEMA__INTEGRATION_DEV_R                                    | SECURITYADMIN   |
# |  59 | SCHEMA__LANDING_GLOBAL_DEV_R                                 | SECURITYADMIN   |
# |  60 | SCHEMA_MARKET_DATA_TEST_R                                    | SECURITYADMIN   |
# |  61 | SCHEMA_REPORTING_DBS_OPERATION_PERFORMANCE_DEV_R             | SECURITYADMIN   |
# |  62 | DATABASE_AQUILA_TEST_R                                       | SYSADMIN        |
# |  63 | SCHEMA_DBT_JRUIZ_DEV_R                                       | ACCOUNTADMIN    |
# |  64 | SCHEMA_DBT_SFATMI_DEV_R                                      | SECURITYADMIN   |
# |  65 | SCHEMA_DBT_SPOPA_DEV_R                                       | ACCOUNTADMIN    |
# |  66 | SCHEMA_DEP_ENERGYINFRASTRUCTURE_PROD_R                       | SECURITYADMIN   |
# |  67 | SCHEMA_DEP_PFM_CE_DEV_R                                      | SECURITYADMIN   |
# |  68 | SCHEMA_DWH_BUSINESS_CORE_DEV_R                               | SECURITYADMIN   |
# |  69 | SCHEMA_DWH_BUSINESS_CORE_PROD_R                              | SECURITYADMIN   |
# |  70 | SCHEMA_DWH_META_PROD_R                                       | SECURITYADMIN   |
# |  71 | SCHEMA_RAW_AIFEXPERT_TEST_R                                  | SECURITYADMIN   |
# |  72 | SCHEMA_RAW_BREEZE_PROD_R                                     | SECURITYADMIN   |
# |  73 | SCHEMA_RAW_COMPASS_PROD_R                                    | SECURITYADMIN   |
# |  74 | SCHEMA_RAW_COMPASS_TEST_R                                    | SECURITYADMIN   |
# |  75 | SCHEMA_RAW_ENAPPSYS_TEST_R                                   | ACCOUNTADMIN    |
# |  76 | SCHEMA_RAW_EU_DEPO_BANK_DEV_R                                | SECURITYADMIN   |
# |  77 | SCHEMA_RAW_ITM_PROD_R                                        | SECURITYADMIN   |
# |  78 | SCHEMA_RAW_JIRA_DEV_R                                        | SECURITYADMIN   |
# |  79 | SCHEMA_RAW_OPUS_DEV_R                                        | SECURITYADMIN   |
# |  80 | SCHEMA_RAW_SALESFORCE_TEST_R                                 | SECURITYADMIN   |
# |  81 | SCHEMA_DBT_MFORNERO_DEV_R                                    | SECURITYADMIN   |
# |  82 | SCHEMA_DBT_MHACKER_DEV_R                                     | SECURITYADMIN   |
# |  83 | SCHEMA_DBT_MSHARKAR_DEV_R                                    | SECURITYADMIN   |
# |  84 | SCHEMA_DBT_RHASKIA_DEV_R                                     | SECURITYADMIN   |
# |  85 | SCHEMA_DBT_VSABEV_DEV_R                                      | ACCOUNTADMIN    |
# |  86 | SCHEMA_DEP_ENERGYINFRASTRUCTURE_TEST_R                       | SECURITYADMIN   |
# |  87 | SCHEMA_DEP_FINANCE_PROD_R                                    | SECURITYADMIN   |
# |  88 | SCHEMA_DEP_PFM_CE_PROD_R                                     | SECURITYADMIN   |
# |  89 | SCHEMA_DWH_RAW_CORE_TEST_R                                   | SECURITYADMIN   |
# |  90 | SCHEMA_DWH_REPORTING_PROD_R                                  | SECURITYADMIN   |
# |  91 | SCHEMA_ODS_MARKET_DATA_DEV_R                                 | SECURITYADMIN   |
# |  92 | SCHEMA_ODS_MARKET_DATA_PROD_R                                | SECURITYADMIN   |
# |  93 | SCHEMA_RAW_ARDOQ_DEV_R                                       | SECURITYADMIN   |
# |  94 | SCHEMA_RAW_ARDOQ_PROD_R                                      | SECURITYADMIN   |
# |  95 | SCHEMA_RAW_ARDOQ_TEST_R                                      | SECURITYADMIN   |
# |  96 | SCHEMA_RAW_CAPTIVA_PROD_R                                    | SECURITYADMIN   |
# |  97 | SCHEMA_RAW_CODE_REFERENCE_TABLES_PROD_R                      | SECURITYADMIN   |
# |  98 | SCHEMA_RAW_DIGITAL_ECONOMICAL_STUDY_TEST_R                   | SECURITYADMIN   |
# |  99 | SCHEMA_RAW_ENAPPSYS_PROD_R                                   | ACCOUNTADMIN    |
# | 100 | SCHEMA_RAW_ENTSOE_DEV_R                                      | SECURITYADMIN   |
# | 101 | SCHEMA_RAW_ESG_PROD_R                                        | ACCOUNTADMIN    |
# | 102 | SCHEMA_RAW_FLAT_FILE_DEV_R                                   | SECURITYADMIN   |
# | 103 | SCHEMA_RAW_FLAT_FILE_TEST_R                                  | SECURITYADMIN   |
# | 104 | SCHEMA_RAW_IRRADIATION_DEV_R                                 | SECURITYADMIN   |
# | 105 | SCHEMA_RAW_JIRA_TEST_R                                       | SECURITYADMIN   |
# | 106 | SCHEMA_RAW_MICROSOFT_GRAPH_API_DEV_R                         | SECURITYADMIN   |
# | 107 | SCHEMA_RAW_MICROSOFT_GRAPH_API_TEST_R                        | SECURITYADMIN   |
# | 108 | SCHEMA_RAW_NEO_PROD_R                                        | ACCOUNTADMIN    |
# | 109 | SCHEMA_RAW_QBI_DEV_R                                         | ACCOUNTADMIN    |
# | 110 | SCHEMA_REPORTING_COMPANY_STRUCTURE_PROD_R                    | SECURITYADMIN   |
# | 111 | SCHEMA_REPORTING_COMPANY_STRUCTURE_TEST_R                    | SECURITYADMIN   |
# | 112 | SCHEMA_REPORTING_COMPASS_DEV_R                               | ACCOUNTADMIN    |
# | 113 | SCHEMA_REPORTING_COMPASS_TEST_R                              | ACCOUNTADMIN    |
# | 114 | SCHEMA_REPORTING_ENTSOE_TEST_R                               | SECURITYADMIN   |
# | 115 | SCHEMA_REPORTING_FINANCE_OPERATIONS_SPAIN_DEV_R              | SECURITYADMIN   |
# | 116 | SCHEMA_REPORTING_FINANCE_SOUTH_EUROPE_TEST_R                 | ACCOUNTADMIN    |
# | 117 | SCHEMA_REPORTING_NEO_DEV_R                                   | ACCOUNTADMIN    |
# | 118 | SCHEMA_REPORTING_NEO_PROD_R                                  | ACCOUNTADMIN    |
# | 119 | SCHEMA_REPORTING_REAL_ESTATE_TEST_R                          | SECURITYADMIN   |
# | 120 | SCHEMA_REPORTING_TAX_SOUTH_EUROPE_PROD_R                     | ACCOUNTADMIN    |
# | 121 | SFLK_R_BI                                                    | AAD_PROVISIONER |
# | 122 | SCHEMA_DBT_OCRAMER_DEV_R                                     | SECURITYADMIN   |
# | 123 | SCHEMA_DWH_REFERENCE_DEV_R                                   | ACCOUNTADMIN    |
# | 124 | SCHEMA_ODS_MARKET_DATA_TEST_R                                | SECURITYADMIN   |
# | 125 | SCHEMA_RAW_DYNAMICS_DEV_R                                    | SECURITYADMIN   |
# | 126 | SCHEMA_RAW_DYNAMO_DEV_R                                      | SECURITYADMIN   |
# | 127 | SCHEMA_RAW_ENAPPSYS_DEV_R                                    | ACCOUNTADMIN    |
# | 128 | SCHEMA_RAW_ENERTRAG_PROD_R                                   | SECURITYADMIN   |
# | 129 | SCHEMA_RAW_EU_DEPO_BANK_PROD_R                               | SECURITYADMIN   |
# | 130 | SCHEMA_RAW_FAST_MODEL_DEV_R                                  | SECURITYADMIN   |
# | 131 | SCHEMA_RAW_ITM_TEST_R                                        | SECURITYADMIN   |
# | 132 | SCHEMA_RAW_METEOCONTROL_PROD_R                               | SECURITYADMIN   |
# | 133 | SCHEMA_RAW_METEOCONTROL_TEST_R                               | SECURITYADMIN   |
# | 134 | SCHEMA_RAW_MICROSOFT_MANAGEMENT_DEV_R                        | SECURITYADMIN   |
# | 135 | SCHEMA_RAW_NEO_TEST_R                                        | ACCOUNTADMIN    |
# | 136 | SCHEMA_RAW_QBI_TEST_R                                        | ACCOUNTADMIN    |
# | 137 | SCHEMA_RAW_REGISTRADORES_PROD_R                              | SECURITYADMIN   |
# | 138 | SCHEMA_RAW_REGISTRADORES_TEST_R                              | SECURITYADMIN   |
# | 139 | SCHEMA_RAW_SALESFORCE_PROD_R                                 | SECURITYADMIN   |
# | 140 | SCHEMA_REPORTING_APOLLO_PROD_R                               | SECURITYADMIN   |
# | 141 | SCHEMA_REPORTING_ATLAS_CALYPSO_DEV_R                         | ACCOUNTADMIN    |
# | 142 | SCHEMA_REPORTING_ATLAS_CALYPSO_PROD_R                        | ACCOUNTADMIN    |
# | 143 | SCHEMA_REPORTING_COLLIBRA_DEV_R                              | SECURITYADMIN   |
# | 144 | SCHEMA_REPORTING_DATA_PROFILE_PROD_R                         | SECURITYADMIN   |
# | 145 | SCHEMA_REPORTING_DATA_PROFILE_TEST_R                         | SECURITYADMIN   |
# | 146 | SCHEMA_REPORTING_ENTSOE_DEV_R                                | SECURITYADMIN   |
# | 147 | SCHEMA_REPORTING_ESG_DEV_R                                   | SECURITYADMIN   |
# | 148 | SCHEMA_REPORTING_ESG_PAI_INDICATORS_TEST_R                   | ACCOUNTADMIN    |
# | 149 | SCHEMA_REPORTING_ESG_PROD_R                                  | SECURITYADMIN   |
# | 150 | SCHEMA_REPORTING_FAST_MODEL_DEV_R                            | ACCOUNTADMIN    |
# | 151 | SCHEMA_REPORTING_FAST_MODEL_PROD_R                           | ACCOUNTADMIN    |
# | 152 | SCHEMA_REPORTING_FINANCE_SOUTH_EUROPE_PROD_R                 | ACCOUNTADMIN    |
# | 153 | SCHEMA_REPORTING_HYDROPOWER_DEV_R                            | SECURITYADMIN   |
# | 154 | SCHEMA_REPORTING_REAL_ESTATE_DIGITAL_ECONOMICAL_STUDY_PROD_R | SECURITYADMIN   |
# | 155 | SCHEMA_REPORTING_SALES_DEV_R                                 | SECURITYADMIN   |
# | 156 | SCHEMA_RAW_ASEPREL_DEV_R                                     | SECURITYADMIN   |
# | 157 | SCHEMA_RAW_IDEALISTA_TEST_R                                  | SECURITYADMIN   |
# | 158 | SCHEMA_REPORTING_ENTSOE_PROD_R                               | SECURITYADMIN   |
# | 159 | SCHEMA_DBT_MCREMER_DEV_R                                     | SECURITYADMIN   |
# | 160 | SCHEMA_DBT_RMALLAVARAPU_DEV_R                                | ACCOUNTADMIN    |
# | 161 | SCHEMA_DEP_FINANCE_TEST_R                                    | SECURITYADMIN   |
# | 162 | SCHEMA_DEP_PFM_CE_TEST_R                                     | SECURITYADMIN   |
# | 163 | SCHEMA_DEP_RISK_ANALYTICS_TEST_R                             | ACCOUNTADMIN    |
# | 164 | SCHEMA_DWH_RAW_CORE_PROD_R                                   | SECURITYADMIN   |
# | 165 | SCHEMA_DWH_REPORTING_DEV_R                                   | SECURITYADMIN   |
# | 166 | SCHEMA_DWH_STAG_PROD_R                                       | SECURITYADMIN   |
# | 167 | SCHEMA_RAW_CAPTIVA_TEST_R                                    | SECURITYADMIN   |
# | 168 | SCHEMA_RAW_COMPASS_DEV_R                                     | SECURITYADMIN   |
# | 169 | SCHEMA_RAW_DIGITAL_ECONOMICAL_STUDY_PROD_R                   | SECURITYADMIN   |
# | 170 | SCHEMA_RAW_ENERTRAG_TEST_R                                   | SECURITYADMIN   |
# | 171 | SCHEMA_RAW_FLAT_FILE_PROD_R                                  | SECURITYADMIN   |
# | 172 | SCHEMA_RAW_IDEALISTA_DEV_R                                   | SECURITYADMIN   |
# | 173 | SCHEMA_RAW_METER_DATA_PROD_R                                 | SECURITYADMIN   |
# | 174 | SCHEMA_RAW_OPUS_PROD_R                                       | SECURITYADMIN   |
# | 175 | SCHEMA_RAW_OPUS_TEST_R                                       | SECURITYADMIN   |
# | 176 | SCHEMA_RAW_POWER_BI_PROD_R                                   | SECURITYADMIN   |
# | 177 | SCHEMA_RAW_SHAREFLEX_TEST_R                                  | SECURITYADMIN   |
# | 178 | SCHEMA_RAW_TRMTRACKER_DEV_R                                  | SECURITYADMIN   |
# | 179 | SCHEMA_RAW_WHS_TEST_R                                        | SECURITYADMIN   |
# | 180 | SCHEMA_REPORTING_COLLIBRA_TEST_R                             | SECURITYADMIN   |
# | 181 | SCHEMA_REPORTING_COMPANY_STRUCTURE_DEV_R                     | SECURITYADMIN   |
# | 182 | SCHEMA_REPORTING_ENRG_DEV_R                                  | SECURITYADMIN   |
# | 183 | SCHEMA_REPORTING_ENRG_PROD_R                                 | SECURITYADMIN   |
# | 184 | SCHEMA_REPORTING_FINANCE_OPERATIONS_EUROPE_N_AND_S_PROD_R    | SECURITYADMIN   |
# | 185 | SCHEMA_REPORTING_FINANCE_TEST_R                              | SECURITYADMIN   |
# | 186 | SCHEMA_REPORTING_MARKET_DATA_DEV_R                           | SECURITYADMIN   |
# | 187 | SCHEMA_REPORTING_MARKET_DATA_TEST_R                          | SECURITYADMIN   |
# | 188 | SCHEMA_REPORTING_PKG_DBT_ARTIFACTS_TEST_R                    | SECURITYADMIN   |
# | 189 | SCHEMA_REPORTING_QBI_TEST_R                                  | SECURITYADMIN   |
# | 190 | SCHEMA_REPORTING_REAL_ESTATE_DIGITAL_ECONOMICAL_STUDY_DEV_R  | SECURITYADMIN   |
# | 191 | SCHEMA_DWH_RAW_CORE_DEV_R                                    | SECURITYADMIN   |
# | 192 | SCHEMA_DWH_REFERENCE_PROD_R                                  | ACCOUNTADMIN    |
# | 193 | SCHEMA_DWH_STAG_DEV_R                                        | SECURITYADMIN   |
# | 194 | SCHEMA_DWH_STAG_TEST_R                                       | SECURITYADMIN   |
# | 195 | SCHEMA_RAW_ASEPREL_PROD_R                                    | SECURITYADMIN   |
# | 196 | SCHEMA_RAW_CAPTIVA_DEV_R                                     | SECURITYADMIN   |
# | 197 | SCHEMA_RAW_CODE_REFERENCE_TABLES_TEST_R                      | SECURITYADMIN   |
# | 198 | SCHEMA_RAW_DIGITAL_ECONOMICAL_STUDY_DEV_R                    | SECURITYADMIN   |
# | 199 | SCHEMA_RAW_DYNAMICS_PROD_R                                   | SECURITYADMIN   |
# | 200 | SCHEMA_RAW_DYNAMICS_TEST_R                                   | SECURITYADMIN   |
# | 201 | SCHEMA_RAW_ENTSOE_PROD_R                                     | SECURITYADMIN   |
# | 202 | SCHEMA_RAW_ENTSOE_TEST_R                                     | SECURITYADMIN   |
# | 203 | SCHEMA_RAW_ESG_DEV_R                                         | ACCOUNTADMIN    |
# | 204 | SCHEMA_RAW_FAST_MODEL_TEST_R                                 | SECURITYADMIN   |
# | 205 | SCHEMA_RAW_IDEALISTA_PROD_R                                  | SECURITYADMIN   |
# | 206 | SCHEMA_RAW_ITM_DEV_R                                         | SECURITYADMIN   |
# | 207 | SCHEMA_RAW_METER_DATA_DEV_R                                  | SECURITYADMIN   |
# | 208 | SCHEMA_RAW_METER_DATA_TEST_R                                 | SECURITYADMIN   |
# | 209 | SCHEMA_RAW_MICROSOFT_GRAPH_API_PROD_R                        | SECURITYADMIN   |
# | 210 | SCHEMA_RAW_MICROSOFT_MANAGEMENT_PROD_R                       | SECURITYADMIN   |
# | 211 | SCHEMA_RAW_POWER_BI_TEST_R                                   | SECURITYADMIN   |
# | 212 | SCHEMA_RAW_REGISTRADORES_DEV_R                               | SECURITYADMIN   |
# | 213 | SCHEMA_RAW_TRMTRACKER_PROD_R                                 | SECURITYADMIN   |
# | 214 | SCHEMA_RAW_TRMTRACKER_TEST_R                                 | SECURITYADMIN   |
# | 215 | SCHEMA_RAW_WHS_DEV_R                                         | SECURITYADMIN   |
# | 216 | SCHEMA_RAW_WHS_PROD_R                                        | SECURITYADMIN   |
# | 217 | SCHEMA_REPORTING_ACCESS_REVIEW_DEV_R                         | SECURITYADMIN   |
# | 218 | SCHEMA_REPORTING_ACCESS_REVIEW_PROD_R                        | SECURITYADMIN   |
# | 219 | SCHEMA_REPORTING_ACCESS_REVIEW_TEST_R                        | SECURITYADMIN   |
# | 220 | SCHEMA_REPORTING_APOLLO_TEST_R                               | SECURITYADMIN   |
# | 221 | SCHEMA_REPORTING_ATLAS_CALYPSO_TEST_R                        | ACCOUNTADMIN    |
# | 222 | SCHEMA_REPORTING_COMPASS_PROD_R                              | ACCOUNTADMIN    |
# | 223 | SCHEMA_REPORTING_DATA_PROFILE_DEV_R                          | SECURITYADMIN   |
# | 224 | SCHEMA_REPORTING_ESG_PAI_INDICATORS_DEV_R                    | ACCOUNTADMIN    |
# | 225 | SCHEMA_REPORTING_ESG_TEST_R                                  | SECURITYADMIN   |
# | 226 | SCHEMA_REPORTING_FAST_MODEL_TEST_R                           | ACCOUNTADMIN    |
# | 227 | SCHEMA_REPORTING_FINANCE_DEV_R                               | SECURITYADMIN   |
# | 228 | SCHEMA_REPORTING_FINANCE_OPERATIONS_EUROPE_N_AND_S_TEST_R    | SECURITYADMIN   |
# | 229 | SCHEMA_REPORTING_FINANCE_OPERATIONS_PROD_R                   | SECURITYADMIN   |
# | 230 | SCHEMA_REPORTING_FINANCE_OPERATIONS_TEST_R                   | SECURITYADMIN   |
# | 231 | SCHEMA_REPORTING_MMG_DEV_R                                   | ACCOUNTADMIN    |
# | 232 | SCHEMA_REPORTING_MMG_TEST_R                                  | ACCOUNTADMIN    |
# | 233 | SCHEMA_REPORTING_MONITORING_DEV_R                            | SECURITYADMIN   |
# | 234 | SCHEMA_REPORTING_NEO_TEST_R                                  | ACCOUNTADMIN    |
# | 235 | SCHEMA_REPORTING_PARETO_PARTNER_FUND_DEV_R                   | SECURITYADMIN   |
# | 236 | SCHEMA_REPORTING_PARETO_PARTNER_FUND_PROD_R                  | SECURITYADMIN   |
# | 237 | SCHEMA_REPORTING_PKG_DBT_ARTIFACTS_DEV_R                     | SECURITYADMIN   |
# | 238 | SCHEMA_REPORTING_QBI_DEV_R                                   | SECURITYADMIN   |
# | 239 | SCHEMA_REPORTING_REAL_ESTATE_DEV_R                           | SECURITYADMIN   |
# | 240 | SCHEMA_RAW_SALESFORCE_DEV_R                                  | SECURITYADMIN   |
# | 241 | SCHEMA_REPORTING_FINANCE_SOUTH_EUROPE_DEV_R                  | ACCOUNTADMIN    |
# | 242 | SCHEMA_REPORTING_MONITORING_PROD_R                           | SECURITYADMIN   |
# | 243 | SCHEMA_REPORTING_REAL_ESTATE_PROD_R                          | SECURITYADMIN   |
# | 244 | SCHEMA_MARKET_DATA_PROD_R                                    | SECURITYADMIN   |
# | 245 | SCHEMA_RAW_ENERTRAG_DEV_R                                    | SECURITYADMIN   |
# | 246 | SCHEMA_REPORTING_DBS_OPERATION_PERFORMANCE_TEST_R            | SECURITYADMIN   |
# | 247 | SCHEMA_REPORTING_FINANCE_OPERATIONS_DEV_R                    | SECURITYADMIN   |
# | 248 | SCHEMA_REPORTING_FINANCE_OPERATIONS_SPAIN_PROD_R             | SECURITYADMIN   |
# | 249 | SCHEMA_REPORTING_FINANCE_PROD_R                              | SECURITYADMIN   |
# | 250 | SCHEMA_REPORTING_MARKET_DATA_PROD_R                          | SECURITYADMIN   |
# | 251 | SCHEMA_REPORTING_PKG_DBT_ARTIFACTS_PROD_R                    | SECURITYADMIN   |
# | 252 | SCHEMA_REPORTING_SALES_TEST_R                                | SECURITYADMIN   |
# | 253 | SCHEMA_REPORTING_TAX_SOUTH_EUROPE_DEV_R                      | ACCOUNTADMIN    |
# | 254 | SCHEMA_REPORTING_TAX_SOUTH_EUROPE_TEST_R                     | ACCOUNTADMIN    |
# | 255 | SCHEMA_REPORTING_TECHNICAL_DATA_PROD_R                       | SECURITYADMIN   |
# | 256 | SCHEMA_REPORTING_TECHNICAL_DATA_TEST_R                       | SECURITYADMIN   |
# | 257 | SCHEMA_SNOWFLAKE_PROD_R                                      | SECURITYADMIN   |
# | 258 | SCHEMA_SNOWFLAKE_TEST_R                                      | SECURITYADMIN   |
# | 259 | SCHEMA__INTEGRATION_PROD_R                                   | SECURITYADMIN   |
# | 260 | SCHEMA__LANDING_GLOBAL_TEST_R                                | SECURITYADMIN   |
# | 261 | SCHEMA_RAW_IRRADIATION_TEST_R                                | SECURITYADMIN   |
# | 262 | SCHEMA_RAW_MICROSOFT_MANAGEMENT_TEST_R                       | SECURITYADMIN   |
# | 263 | SCHEMA_RAW_POWER_BI_DEV_R                                    | SECURITYADMIN   |
# | 264 | SCHEMA_RAW_QBI_PROD_R                                        | ACCOUNTADMIN    |
# | 265 | SCHEMA_RAW_SHAREFLEX_DEV_R                                   | SECURITYADMIN   |
# | 266 | SCHEMA_RAW_SHAREFLEX_PROD_R                                  | SECURITYADMIN   |
# | 267 | SCHEMA_REPORTING_DBS_OPERATION_PERFORMANCE_PROD_R            | SECURITYADMIN   |
# | 268 | SCHEMA_REPORTING_ENRG_TEST_R                                 | SECURITYADMIN   |
# | 269 | SCHEMA_REPORTING_ESG_PAI_INDICATORS_PROD_R                   | ACCOUNTADMIN    |
# | 270 | SCHEMA_REPORTING_FINANCE_OPERATIONS_SPAIN_TEST_R             | SECURITYADMIN   |
# | 271 | SCHEMA_REPORTING_HYDROPOWER_PROD_R                           | SECURITYADMIN   |
# | 272 | SCHEMA_REPORTING_HYDROPOWER_TEST_R                           | SECURITYADMIN   |
# | 273 | SCHEMA_REPORTING_MMG_PROD_R                                  | ACCOUNTADMIN    |
# | 274 | SCHEMA_REPORTING_MONITORING_TEST_R                           | SECURITYADMIN   |
# | 275 | SCHEMA_REPORTING_PARETO_PARTNER_FUND_TEST_R                  | SECURITYADMIN   |
# | 276 | SCHEMA_REPORTING_REAL_ESTATE_DIGITAL_ECONOMICAL_STUDY_TEST_R | SECURITYADMIN   |
# | 277 | SCHEMA_REPORTING_SALES_PROD_R                                | SECURITYADMIN   |
# | 278 | SCHEMA_REPORTING_TECHNICAL_DATA_DEV_R                        | SECURITYADMIN   |
# | 279 | SCHEMA__INTEGRATION_TEST_R                                   | SECURITYADMIN   |
# | 280 | SCHEMA__LANDING_GLOBAL_PROD_R                                | SECURITYADMIN   |
# | 281 | SCHEMA_REPORTING_APOLLO_DEV_R                                | SECURITYADMIN   |
# +-----+--------------------------------------------------------------+-----------------+
